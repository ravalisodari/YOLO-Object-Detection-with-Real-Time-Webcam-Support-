# %%
#pip install opencv-python ultralytics

# %%
from ultralytics import YOLO

# %%
path = r"C:\Users\USER\Downloads\download.jpg"

# %%
# yolo = Freame
# Version = 26
# nano = faster but not much accurate
# s =small
# medium = medium
# l=large
# X= extra large - slower but accurate

# %%
import cv2

# %%
model = YOLO("yolo26n.pt")  # Nano model (fastest)

# %%
result=model(source=path)
cv2.imshow('Tree',result[0].plot())
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# image 1/1 C:\Users\USER\Downloads\download.jpg: 416x640 1 apple, 159.9ms
# Speed: 4.7ms preprocess, 159.9ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)

# %% [markdown]
# # Video

# %%
import cv2
from ultralytics import YOLO

# Load YOLO model
model = YOLO("yolov8n.pt")

path = r"C:\Users\USER\Downloads\cricket.mp4"
video = cv2.VideoCapture(path)

while True:
    success, frame = video.read()

    if not success:
        break

    result = model(frame)
    image = result[0].plot()

    cv2.imshow("Video", image)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video.release()
cv2.destroyAllWindows()
# Out:
# ...
#
# 0: 384x640 2 persons, 140.6ms
# Speed: 3.3ms preprocess, 140.6ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 257.9ms
# Speed: 6.0ms preprocess, 257.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 193.9ms
# Speed: 6.3ms preprocess, 193.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 169.9ms
# Speed: 6.1ms preprocess, 169.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 176.6ms
# Speed: 4.9ms preprocess, 176.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 182.0ms
# Speed: 3.5ms preprocess, 182.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 186.9ms
# Speed: 5.0ms preprocess, 186.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 183.1ms
# ...

# %%
image = cv2.imread("❤️❤️.jpeg")

# %%
results = model(image)
# Out:
# WARNING 'source' is missing. Using 'source=C:\Users\USER\anaconda4\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\USER\anaconda4\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 192.6ms
# image 2/2 C:\Users\USER\anaconda4\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 127.9ms
# Speed: 6.5ms preprocess, 160.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
annotated_image = results[0].plot()

# %%
cv2.imshow("O", annotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        break

    results = model(frame)

    annotated_frame = results[0].plot()

    cv2.imshow("Object Detection", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 351.2ms
# Speed: 11.8ms preprocess, 351.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 290.9ms
# Speed: 7.8ms preprocess, 290.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.2ms
# Speed: 3.2ms preprocess, 222.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.7ms
# Speed: 8.2ms preprocess, 222.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 230.0ms
# Speed: 9.4ms preprocess, 230.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.0ms
# Speed: 4.6ms preprocess, 193.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.1ms
# Speed: 3.3ms preprocess, 190.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.3ms
# ...

# %%
video = cv2.VideoCapture(0)

# Threshold Value for EAR
EAR_THRESHOLD = 0.2
EAR_COUNTER = 0
EAR_FRAMES = 30

# Threshold Value for MAR
MAR_THRESHOLD = 0.5
MAR_COUNTER = 0
MAR_FRAMES = 30

while True:
    success, frame = video.read()

    if not success:
        break

    image = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)

    face = mp.Image(image_format=mp.ImageFormat.SRGB,data = image)
    time_frame = int(time.time() * 1000)

    result = detector.detect_for_video(image=face,timestamp_ms=time_frame)

    if result.face_landmarks:
        landmark = result.face_landmarks[0]
    
        LEAR = left_eye_aspect_ratio(landmark)
        REAR = right_eye_aspect_ratio(landmark)

        avg_ear = (LEAR + REAR) / 2
        mar = mouth_aspect_ratio(landmark)


        cv2.putText(img = frame, 
                    text = f'EAR : {avg_ear}', 
                    org = (20,30), 
                    fontFace = cv2.FONT_HERSHEY_TRIPLEX, 
                    fontScale = 1, 
                    color = (255,0,0), 
                    thickness = 1)

        cv2.putText(img = frame, 
                    text = f'MAR : {mar}', 
                    org = (20,60), 
                    fontFace = cv2.FONT_HERSHEY_TRIPLEX, 
                    fontScale = 1, 
                    color = (255,0,0), 
                    thickness = 1)



        
        if (avg_ear < EAR_THRESHOLD):
            EAR_COUNTER = EAR_COUNTER + 1
        else:
            EAR_COUNTER = 0

        if (mar > MAR_THRESHOLD):
            MAR_COUNTER = MAR_COUNTER + 1
        else:
            MAR_COUNTER = 0


        if (EAR_COUNTER > EAR_FRAMES) or (MAR_COUNTER > MAR_FRAMES):
            cv2.putText(img = frame, 
                    text = "You Are Drowzy", 
                    org = (50,100), 
                    fontFace = cv2.FONT_HERSHEY_TRIPLEX, 
                    fontScale = 2, 
                    color = (0,0,255), 
                    thickness = 2)

            winsound.Beep(500,1000)
        
    
    cv2.imshow("Webcam",frame)

    if cv2.waitKey(1) == ord('q'):
        break
video.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 21
#      17     break
#      19 image = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
# ---> 21 face = mp.Image(image_format=mp.ImageFormat.SRGB,data = image)
#      22 time_frame = int(time.time() * 1000)
#      24 result = detector.detect_for_video(image=face,timestamp_ms=time_frame)
#
# NameError: name 'mp' is not defined
